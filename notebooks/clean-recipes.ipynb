# %% [markdown]
# Used to reformat recipes for easier processing on backend (e.g., standard format for nutritional values)

# %%
import pandas as pd

# %%
df = pd.read_csv('RAW_recipes.csv')

# %%
df = df.replace(r'\n', ' ', regex=True)
df = df.replace(r'\r', ' ', regex=True)
df = df.replace(r'"', ' ', regex=True)

# %%
import re

def cleanName(string):
    string = str(string)
    return re.sub(r'\s+', r' ', string)

df['name'] = df['name'].apply(cleanName)

# %%
def nutritionIntegers(nutrition):
    nutrition = re.sub(r'\[', r'', nutrition)
    nutrition = re.sub(r'\]', r'', nutrition)
    return [float(nutrition) for nutrition in nutrition.split(', ')]

df['nutrition_integers'] = df['nutrition'].apply(nutritionIntegers)

# %%
def addNutritionDetails(df):
    labels = ['calories', 'fat', 'sugar', 'sodium', 'protein', 'sat_fat', 'carbs']
    for i, l in enumerate(labels):
        df[l] = df['nutrition_integers'].apply(lambda n: n[i])

addNutritionDetails(df)

# %%
def cleanSteps(steps):
    steps = re.sub(r'\[', r'', steps)
    steps = re.sub(r'\]', r'', steps)
    return [step.strip() for step in steps.split(', ')]

df['steps'].apply(cleanSteps)
# Out:
# 0         ['make a choice and proceed with recipe', 'dep...
# 1         ['preheat oven to 425 degrees f', 'press dough...
# 2         ['brown ground beef in large pot', 'add choppe...
# 3         ['place potatoes in a large pot of lightly sal...
# 4         ['mix all ingredients& boil for 2 1 / 2 hours,...
#                                 ...
# 231632    ['heat oil in a 4-quart dutch oven', 'add cele...
# 231633          ['mix all ingredients together thoroughly']
# 231634    ['in a bowl, combine the mashed yolks and mayo...
# 231635    ['place melted butter in a large mixing bowl a...
# 231636    ['whip sugar and shortening in a large bowl, a...
# Name: steps, Length: 231637, dtype: object

# %%
labels = ['calories', 'fat', 'sugar', 'sodium', 'protein', 'sat_fat', 'carbs']

databaseColumns = ['id', 'name', 'description', 'n_steps', 'minutes', 'steps']
databaseColumns += labels

cleaned_df = df.loc[:, databaseColumns]
cleaned_df
# Out:
#             id                                        name  \
# 0       137739    arriba baked winter squash mexican style
# 1        31490             a bit different breakfast pizza
# 2       112140                    all in the kitchen chili
# 3        59389                           alouette potatoes
# 4        44061            amish tomato ketchup for canning
# ...        ...                                         ...
# 231632  486161                                 zydeco soup
# 231633  493372                            zydeco spice mix
# 231634  308080                   zydeco ya ya deviled eggs
# 231635  298512        cookies by design cookies on a stick
# 231636  298509  cookies by design sugar shortbread cookies
#
#                                               description  n_steps  minutes  \
# 0       autumn is my favorite time of year to cook! th...       11       55
# 1       this recipe calls for the crust to be prebaked...        9       30
# 2       this modified version of 'mom's' chili was a h...        6      130
# 3       this is a super easy, great tasting, make ahea...       11       45
# 4       my dh's amish mother raised him on this recipe...        5      190
# ...                                                   ...      ...      ...
# 231632  this is a delicious soup that i originally fou...        7       60
# 231633    this spice mix will make your taste buds dance!        1        5
# 231634                          deviled eggs, cajun-style        7       40
# 231635  i've heard of the 'cookies by design' company,...        9       29
# 231636  i've heard of the 'cookies by design' company,...        5       20
#
#                                                     steps  calories   fat  \
# 0       ['make a choice and proceed with recipe', 'dep...      51.5   0.0
# 1       ['preheat oven to 425 degrees f', 'press dough...     173.4  18.0
# 2       ['brown ground beef in large pot', 'add choppe...     269.8  22.0
# 3       ['place potatoes in a large pot of lightly sal...     368.1  17.0
# 4       ['mix all ingredients& boil for 2 1 / 2 hours ...     352.9   1.0
# ...                                                   ...       ...   ...
# 231632  ['heat oil in a 4-quart dutch oven', 'add cele...     415.2  26.0
# 231633        ['mix all ingredients together thoroughly']      14.8   0.0
# 231634  ['in a bowl , combine the mashed yolks and may...      59.2   6.0
# 231635  ['place melted butter in a large mixing bowl a...     188.0  11.0
# 231636  ['whip sugar and shortening in a large bowl , ...     174.9  14.0
#
#         sugar  sodium  protein  sat_fat  carbs
# 0        13.0     0.0      2.0      0.0    4.0
# 1         0.0    17.0     22.0     35.0    1.0
# 2        32.0    48.0     39.0     27.0    5.0
# 3        10.0     2.0     14.0      8.0   20.0
# 4       337.0    23.0      3.0      0.0   28.0
# ...       ...     ...      ...      ...    ...
# 231632   34.0    26.0     44.0     21.0   15.0
# 231633    2.0    58.0      1.0      0.0    1.0
# 231634    2.0     3.0      6.0      5.0    0.0
# 231635   57.0    11.0      7.0     21.0    9.0
# 231636   33.0     4.0      4.0     11.0    6.0
#
# [231637 rows x 13 columns]

# %%
cleaned_df.to_csv('CLEAN_recipes.csv', index=False)
